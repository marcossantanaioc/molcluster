# %%
#default_exp typing_basics

# %%
#export

from typing import Any, List, Collection, Dict, Set, Sequence, Union, Tuple, Iterator

# %%
#export
__all__ = ['Any', 'List', 'Collection', 'Dict', 'Set', 'Sequence', 'Union', 'Tuple', 'Iterator']

# %%
#hide
from nbdev.export import notebook2script
notebook2script('typing_basics.ipynb')
#from nbdev.export2html import notebook2html; notebook2html()
# Out:
# Converted typing_basics.ipynb.
